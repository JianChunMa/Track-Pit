# %% [markdown]
# # JSON VALUES

# %%
import firebase_admin
from firebase_admin import credentials, firestore
import datetime
import json
import pytz  # make sure you have pytz installed

if not firebase_admin._apps:
    cred = credentials.Certificate("track-pit-firebase-adminsdk-fbsvc-989e750375.json")
    firebase_admin.initialize_app(cred)

db = firestore.client()

# Malaysia timezone
MALAYSIA_TZ = pytz.timezone("Asia/Kuala_Lumpur")


def serialize_value(value):
    """Convert Firestore types into JSON-safe Python types."""
    from google.cloud.firestore_v1._helpers import DatetimeWithNanoseconds

    if isinstance(value, bytes):
        return value.decode("utf-8", errors="ignore")

    if isinstance(value, (datetime.datetime, DatetimeWithNanoseconds)):
        # Ensure timezone-aware datetime
        if value.tzinfo is None:
            value = value.replace(tzinfo=datetime.timezone.utc)
        # Convert to Malaysia timezone
        local_dt = value.astimezone(MALAYSIA_TZ)
        # Format to readable string
        return local_dt.strftime("%d %b %Y, %I:%M %p")  # Example: "20 Sep 2025, 01:45 AM"

    if isinstance(value, dict):
        return {k: serialize_value(v) for k, v in value.items()}

    if isinstance(value, list):
        return [serialize_value(v) for v in value]

    return value


def fetch_collection(path, sample_limit=None):
    """
    Recursively fetch all documents & subcollections under a collection path.
    Returns nested dict.
    """
    result = {}
    ref = db.collection(path)
    docs = ref.stream() if sample_limit is None else ref.limit(sample_limit).stream()

    for doc in docs:
        doc_data = {k: serialize_value(v) for k, v in doc.to_dict().items()}

        # Handle subcollections
        sub_data = {}
        for subcol in ref.document(doc.id).collections():
            sub_data[subcol.id] = fetch_collection(f"{path}/{doc.id}/{subcol.id}")

        if sub_data:
            doc_data["_subcollections"] = sub_data

        result[doc.id] = doc_data

    return result


# --- Dump specific top-level collections ---
all_data = {
    "users": fetch_collection("users"),
    # "plates": fetch_collection("plates"),
    # "feedback": fetch_collection("feedback"),
    # "faqs": fetch_collection("faqs"),
}

print(json.dumps(all_data, indent=2, ensure_ascii=False))
# Out:
# {
#   "users": {
#     "4nI4UHmPifPLkwGsWu0zJDy68oE2": {
#       "points": 0,
#       "email": "a@a.com",
#       "updatedAt": "18 Sep 2025, 07:23 PM",
#       "fullName": "aaa",
#       "createdAt": "18 Sep 2025, 07:23 PM"
#     },
#     "BFt4LbQPViQbya9Hh46xMG912Qr1": {
#       "points": 0,
#       "email": "yylim-wm22@student.tarc.edu.my",
#       "updatedAt": "20 Sep 2025, 01:22 AM",
#       "createdAt": "20 Sep 2025, 01:22 AM",
#       "fullName": "YUET YANG LIM"
#     },
#     "RHok1nfhGBSFuacubmZMer22tKp1": {
#       "fullName": "Lim Yuet Yang",
#       "email": "a@b.com",
#       "updatedAt": "18 Sep 2025, 07:32 PM",
#       "points": 0,
#       "createdAt": "18 Sep 2025, 07:32 PM"
#     },
#     "iiYYy1LD2TYMASxgaW1VzTvRkwe2": {
#       "points": 0,
#       "email": "yigallim@gmail.com",
#       "updatedAt": "20 Sep 2025, 01:22 AM",
#       "createdAt": "20 Sep 2025, 01:22 AM",
#       "fullName": "Ye Yang",
#       "_subcollections": {
#         "services": {
#           "5Zg1spiwEn6lK6om3sjR": {
#             "workshopId": 2,
#             "notes": "Upcoming mock service",
#             "updatedAt": "20 Sep 2025, 02:00 AM",
#             "bookedDateTime": "23 Sep 2025, 02:00 AM",
#             "vehicleId": "TtkkQVThcYodgjnSizKb",
#             "serviceTypeId": 2,
#             "createdAt": "20 Sep 2025, 02:00 AM",
#             "_subcollections": {
#               "statusTimeline": {
#                 "1": {
#                   "completedAt": null,
#                   "status": "inspection"
#                 },
#                 "2": {
#                   "completedAt": null,
#                   "status": "parts_awaiting"
#                 },
#                 "3": {
#                   "completedAt": null,
#                   "status": "in_repair"
#                 },
#                 "4": {
#                   "completedAt": null,
#                   "status": "completed"
#                 }
#               }
#             }
#           },
#           "OqDW77MgyLAG85roeLmA": {
#             "workshopId": 1,
#             "notes": "Upcoming mock service",
#             "updatedAt": "21 Sep 2025, 02:00 AM",
#             "bookedDateTime": "23 Sep 2025, 02:00 AM",
#             "vehicleId": "TtkkQVThcYodgjnSizKb",
#             "serviceTypeId": 1,
#             "createdAt": "21 Sep 2025, 02:00 AM",
#             "_subcollections": {
#               "statusTimeline": {
#                 "1": {
#                   "completedAt": null,
#                   "status": "inspection"
#                 },
#                 "2": {
#                   "completedAt": null,
#                   "status": "parts_awaiting"
#                 },
#                 "3": {
#                   "completedAt": null,
#                   "status": "in_repair"
#                 },
#                 "4": {
#                   "completedAt": null,
#                   "status": "completed"
#                 }
#               }
#             }
#           },
#           "Xsz0nfzx6bIyLai6yMet": {
#             "workshopId": 2,
#             "notes": "Ongoing mock service",
#             "updatedAt": "16 Sep 2025, 10:30 PM",
#             "bookedDateTime": "18 Sep 2025, 10:30 PM",
#             "vehicleId": "TtkkQVThcYodgjnSizKb",
#             "serviceTypeId": 3,
#             "createdAt": "16 Sep 2025, 10:30 PM",
#             "_subcollections": {
#               "statusTimeline": {
#                 "1": {
#                   "completedAt": "18 Sep 2025, 10:30 PM",
#                   "status": "inspection"
#                 },
#                 "2": {
#                   "completedAt": "19 Sep 2025, 12:30 AM",
#                   "status": "parts_awaiting"
#                 },
#                 "3": {
#                   "completedAt": null,
#                   "status": "in_repair"
#                 },
#                 "4": {
#                   "completedAt": null,
#                   "status": "completed"
#                 }
#               }
#             }
#           },
#           "b0YecWP20WjUEBPOkzwC": {
#             "workshopId": 2,
#             "notes": "Completed mock service",
#             "updatedAt": "15 Sep 2025, 08:00 PM",
#             "bookedDateTime": "18 Sep 2025, 08:00 PM",
#             "vehicleId": "TtkkQVThcYodgjnSizKb",
#             "serviceTypeId": 3,
#             "createdAt": "15 Sep 2025, 08:00 PM",
#             "_subcollections": {
#               "statusTimeline": {
#                 "1": {
#                   "completedAt": "18 Sep 2025, 08:00 PM",
#                   "status": "inspection"
#                 },
#                 "2": {
#                   "completedAt": "18 Sep 2025, 10:00 PM",
#                   "status": "parts_awaiting"
#                 },
#                 "3": {
#                   "completedAt": "19 Sep 2025, 12:00 AM",
#                   "status": "in_repair"
#                 },
#                 "4": {
#                   "completedAt": "19 Sep 2025, 02:00 AM",
#                   "status": "completed"
#                 }
#               }
#             }
#           },
#           "do1PhDr78um36kpAtXFf": {
#             "workshopId": 2,
#             "notes": "Ongoing mock service",
#             "updatedAt": "16 Sep 2025, 04:30 PM",
#             "bookedDateTime": "19 Sep 2025, 04:30 PM",
#             "vehicleId": "TtkkQVThcYodgjnSizKb",
#             "serviceTypeId": 3,
#             "createdAt": "16 Sep 2025, 04:30 PM",
#             "_subcollections": {
#               "statusTimeline": {
#                 "1": {
#                   "completedAt": "19 Sep 2025, 04:30 PM",
#                   "status": "inspection"
#                 },
#                 "2": {
#                   "completedAt": null,
#                   "status": "parts_awaiting"
#                 },
#                 "3": {
#                   "completedAt": null,
#                   "status": "in_repair"
#                 },
#                 "4": {
#                   "completedAt": null,
#                   "status": "completed"
#                 }
#               }
#             }
#           },
#           "oc8KPM6KiWOjyhB2gOlX": {
#             "workshopId": 2,
#             "notes": "Ongoing mock service",
#             "updatedAt": "17 Sep 2025, 10:00 PM",
#             "bookedDateTime": "18 Sep 2025, 10:00 PM",
#             "vehicleId": "TtkkQVThcYodgjnSizKb",
#             "serviceTypeId": 2,
#             "createdAt": "17 Sep 2025, 10:00 PM",
#             "_subcollections": {
#               "statusTimeline": {
#                 "1": {
#                   "completedAt": "18 Sep 2025, 10:00 PM",
#                   "status": "inspection"
#                 },
#                 "2": {
#                   "completedAt": "19 Sep 2025, 12:00 AM",
#                   "status": "parts_awaiting"
#                 },
#                 "3": {
#                   "completedAt": null,
#                   "status": "in_repair"
#                 },
#                 "4": {
#                   "completedAt": null,
#                   "status": "completed"
#                 }
#               }
#             }
#           },
#           "vc1XSuuxI9OAht1uCxdi": {
#             "workshopId": 1,
#             "notes": "Completed mock service",
#             "updatedAt": "15 Sep 2025, 02:00 AM",
#             "bookedDateTime": "18 Sep 2025, 02:00 AM",
#             "vehicleId": "TtkkQVThcYodgjnSizKb",
#             "serviceTypeId": 1,
#             "createdAt": "15 Sep 2025, 02:00 AM",
#             "_subcollections": {
#               "statusTimeline": {
#                 "1": {
#                   "completedAt": "18 Sep 2025, 02:00 AM",
#                   "status": "inspection"
#                 },
#                 "2": {
#                   "completedAt": "18 Sep 2025, 04:00 AM",
#                   "status": "parts_awaiting"
#                 },
#                 "3": {
#                   "completedAt": "18 Sep 2025, 06:00 AM",
#                   "status": "in_repair"
#                 },
#                 "4": {
#                   "completedAt": "18 Sep 2025, 08:00 AM",
#                   "status": "completed"
#                 }
#               }
#             }
#           }
#         },
#         "vehicles": {
#           "Fyaq2UWHNqVMY2cQi9cG": {
#             "transmission": "automatic",
#             "year": 2016,
#             "plateNumber": "QEP090",
#             "createdAt": "19 Sep 2025, 04:46 PM",
#             "model": "Honda City Hatchback",
#             "updatedAt": "19 Sep 2025, 04:49 PM",
#             "mileage": 100,
#             "chassisNumber": "3esr5tt6yyyh"
#           },
#           "TtkkQVThcYodgjnSizKb": {
#             "transmission": "automatic",
#             "year": 2017,
#             "plateNumber": "IDK133",
#             "createdAt": "19 Sep 2025, 02:07 AM",
#             "model": "Proton X50",
#             "updatedAt": "19 Sep 2025, 02:07 AM",
#             "mileage": 100,
#             "chassisNumber": "1q2w3e4rcc"
#           },
#           "fkX99XUVbbgVmDPv9OFB": {
#             "transmission": "automatic",
#             "year": 2018,
#             "plateNumber": "QWE123",
#             "createdAt": "19 Sep 2025, 02:01 AM",
#             "model": "Perodua Myvi",
#             "updatedAt": "19 Sep 2025, 02:01 AM",
#             "mileage": 10,
#             "chassisNumber": "1q2w3e4r5g"
#           },
#           "jGFFKi6AZspMX0kecaqH": {
#             "transmission": "automatic",
#             "year": 2012,
#             "plateNumber": "IDK999",
#             "createdAt": "19 Sep 2025, 04:49 PM",
#             "model": "Toyota Harrier",
#             "updatedAt": "19 Sep 2025, 04:49 PM",
#             "mileage": 100,
#             "chassisNumber": "19wodifi9d9e9e"
#           },
#           "wUk88x1Fk1PI1uBJL3qi": {
#             "transmission": "automatic",
#             "year": 2017,
#             "plateNumber": "QE000",
#             "createdAt": "19 Sep 2025, 04:46 PM",
#             "model": "Honda Accord",
#             "updatedAt": "19 Sep 2025, 04:46 PM",
#             "mileage": 100,
#             "chassisNumber": "qq728eurur8ri"
#           }
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# # DESC SHAPE

# %%
import firebase_admin
from firebase_admin import credentials, firestore

if not firebase_admin._apps:
    cred = credentials.Certificate("track-pit-firebase-adminsdk-fbsvc-989e750375.json")
    firebase_admin.initialize_app(cred)

db = firestore.client()


def detect_type(value):
    if isinstance(value, str):
        return "string"
    elif isinstance(value, bool):
        return "bool"
    elif isinstance(value, int):
        return "int"
    elif isinstance(value, float):
        return "float"
    elif isinstance(value, list):
        return "list"
    elif isinstance(value, dict):
        return "map"
    elif hasattr(value, "timestamp"):  # Firestore timestamp
        return "timestamp"
    else:
        return type(value).__name__

def describe_collection(path, depth=0, sample_limit=5):
    indent = "  " * depth
    try:
        docs = db.collection(path).limit(sample_limit).stream()
    except Exception as e:
        print(f"{indent}⚠️ Cannot access {path}: {e}")
        return

    print(f"{indent}Collection: {path}")
    for doc in docs:
        print(f"{indent}  Document ID: {doc.id}")
        data = doc.to_dict()
        for key, val in data.items():
            print(f"{indent}    - {key}: {detect_type(val)}")
        
        # Recurse into subcollections
        subcollections = db.collection(path).document(doc.id).collections()
        for subcol in subcollections:
            describe_collection(f"{path}/{doc.id}/{subcol.id}", depth+2, sample_limit)


# Example: top-level collections
describe_collection("users")       # will recurse into vehicles, bookings, serviceRecords
describe_collection("plates")
describe_collection("feedback")
describe_collection("faqs")
# Out:
# Collection: users
#   Document ID: 4nI4UHmPifPLkwGsWu0zJDy68oE2
#     - points: int
#     - email: string
#     - updatedAt: timestamp
#     - fullName: string
#     - createdAt: timestamp
#   Document ID: BFt4LbQPViQbya9Hh46xMG912Qr1
#     - points: int
#     - email: string
#     - updatedAt: timestamp
#     - createdAt: timestamp
#     - fullName: string
#   Document ID: RHok1nfhGBSFuacubmZMer22tKp1
#     - fullName: string
#     - email: string
#     - updatedAt: timestamp
#     - points: int
#     - createdAt: timestamp
#   Document ID: iiYYy1LD2TYMASxgaW1VzTvRkwe2
#     - points: int
#     - email: string
#     - updatedAt: timestamp
#     - createdAt: timestamp
#     - fullName: string
#     Collection: users/iiYYy1LD2TYMASxgaW1VzTvRkwe2/services
#       Document ID: 3867E755Y9HuFaTeAFLQ
#         - workshopId: int
#         - notes: string
#         - updatedAt: timestamp
#         - bookedDateTime: timestamp
#         - vehicleId: string
#         - serviceTypeId: int
#         - createdAt: timestamp
#         Collection: users/iiYYy1LD2TYMASxgaW1VzTvRkwe2/services/3867E755Y9HuFaTeAFLQ/statusTimeline
#           Document ID: 1
#             - completedAt: timestamp
#             - status: string
#           Document ID: 2
#             - completedAt: NoneType
#             - status: string
#           Document ID: 3
#             - completedAt: NoneType
#             - status: string
#           Document ID: 4
#             - completedAt: NoneType
#             - status: string
#       Document ID: 784dqlCvzFsfrxbQ7Oe1
#         - workshopId: int
#         - notes: string
#         - updatedAt: timestamp
#         - bookedDateTime: timestamp
#         - vehicleId: string
#         - serviceTypeId: int
#         - createdAt: timestamp
#         Collection: users/iiYYy1LD2TYMASxgaW1VzTvRkwe2/services/784dqlCvzFsfrxbQ7Oe1/statusTimeline
#           Document ID: 1
#             - completedAt: NoneType
#             - status: string
#           Document ID: 2
#             - completedAt: NoneType
#             - status: string
#           Document ID: 3
#             - completedAt: NoneType
#             - status: string
#           Document ID: 4
#             - completedAt: NoneType
#             - status: string
#       Document ID: PPR023MPypffPIRVsfV0
#         - workshopId: int
#         - notes: string
#         - updatedAt: timestamp
#         - bookedDateTime: timestamp
#         - vehicleId: string
#         - serviceTypeId: int
#         - createdAt: timestamp
#         Collection: users/iiYYy1LD2TYMASxgaW1VzTvRkwe2/services/PPR023MPypffPIRVsfV0/statusTimeline
#           Document ID: 1
#             - completedAt: timestamp
#             - status: string
#           Document ID: 2
#             - completedAt: NoneType
#             - status: string
#           Document ID: 3
#             - completedAt: NoneType
#             - status: string
#           Document ID: 4
#             - completedAt: NoneType
#             - status: string
#       Document ID: VXg8tq4ALt67STQwFQ8I
#         - workshopId: int
#         - notes: string
#         - updatedAt: timestamp
#         - bookedDateTime: timestamp
#         - vehicleId: string
#         - serviceTypeId: int
#         - createdAt: timestamp
#         Collection: users/iiYYy1LD2TYMASxgaW1VzTvRkwe2/services/VXg8tq4ALt67STQwFQ8I/statusTimeline
#           Document ID: 1
#             - completedAt: timestamp
#             - status: string
#           Document ID: 2
#             - completedAt: NoneType
#             - status: string
#           Document ID: 3
#             - completedAt: NoneType
#             - status: string
#           Document ID: 4
#             - completedAt: NoneType
#             - status: string
#       Document ID: ovWSTd7fC8pPHLshGvlV
#         - workshopId: int
#         - notes: string
#         - updatedAt: timestamp
#         - bookedDateTime: timestamp
#         - vehicleId: string
#         - serviceTypeId: int
#         - createdAt: timestamp
#         Collection: users/iiYYy1LD2TYMASxgaW1VzTvRkwe2/services/ovWSTd7fC8pPHLshGvlV/statusTimeline
#           Document ID: 1
#             - completedAt: NoneType
#             - status: string
#           Document ID: 2
#             - completedAt: NoneType
#             - status: string
#           Document ID: 3
#             - completedAt: NoneType
#             - status: string
#           Document ID: 4
#             - completedAt: NoneType
#             - status: string
#     Collection: users/iiYYy1LD2TYMASxgaW1VzTvRkwe2/vehicles
#       Document ID: Fyaq2UWHNqVMY2cQi9cG
#         - transmission: string
#         - year: int
#         - plateNumber: string
#         - createdAt: timestamp
#         - model: string
#         - updatedAt: timestamp
#         - mileage: int
#         - chassisNumber: string
#       Document ID: TtkkQVThcYodgjnSizKb
#         - transmission: string
#         - year: int
#         - plateNumber: string
#         - createdAt: timestamp
#         - model: string
#         - updatedAt: timestamp
#         - mileage: int
#         - chassisNumber: string
#       Document ID: fkX99XUVbbgVmDPv9OFB
#         - transmission: string
#         - year: int
#         - plateNumber: string
#         - createdAt: timestamp
#         - model: string
#         - updatedAt: timestamp
#         - mileage: int
#         - chassisNumber: string
#       Document ID: jGFFKi6AZspMX0kecaqH
#         - transmission: string
#         - year: int
#         - plateNumber: string
#         - createdAt: timestamp
#         - model: string
#         - updatedAt: timestamp
#         - mileage: int
#         - chassisNumber: string
#       Document ID: wUk88x1Fk1PI1uBJL3qi
#         - transmission: string
#         - year: int
#         - plateNumber: string
#         - createdAt: timestamp
#         - model: string
#         - updatedAt: timestamp
#         - mileage: int
#         - chassisNumber: string
# Collection: plates
#   Document ID: IDK133
#     - uid: string
#     - vehicleId: string
#     - createdAt: timestamp
#   Document ID: IDK999
#     - uid: string
#     - vehicleId: string
#     - createdAt: timestamp
#   Document ID: QE000
#     - uid: string
#     - vehicleId: string
#     - createdAt: timestamp
#   Document ID: QEP090
#     - uid: string
#     - vehicleId: string
#     - createdAt: timestamp
#   Document ID: QWE123
#     - uid: string
#     - vehicleId: string
#     - createdAt: timestamp
# Collection: feedback
#   Document ID: KZNV8ZGJ4ZuryaFcOFtB
#     - uid: string
#     - email: string
#     - rating: int
#     - message: string
#     - timestamp: timestamp
#   Document ID: NVt6L6s5IbKGwtTZveeF
#     - uid: string
#     - email: string
#     - rating: int
#     - message: string
#     - timestamp: timestamp
# Collection: faqs

# %% [markdown]
# # FIREBASE SCHEMA
#
# ### `users/{uid}`
#
# * **Fields**
#
#   * `email` (string)
#   * `fullName` (string)
#   * `points` (int)
#   * `vehicleCount` (int, optional)
#   * `hasCompletedVehicleSetup` (bool, optional)
#   * `createdAt` (timestamp)
#   * `updatedAt` (timestamp)
#
# * **Subcollections**
#
#   * **`vehicles/{vehicleId}`**
#
#     * `plateNumber` (string)
#     * `model` (string)
#     * `year` (int)
#     * `chassisNumber` (string)
#     * `mileage` (int)
#     * `transmission` (string)
#     * `createdAt`, `updatedAt` (timestamp)
#
#   * **`services/{serviceId}`**
#
#     * `vehicleId` (string)
#     * `serviceTypeId` (int)
#     * `workshopId` (int)
#     * `bookedDateTime` (timestamp)
#     * `notes` (string)
#     * `createdAt`, `updatedAt` (timestamp)
#
#   * **`invoices/{invoiceId}`**
#
#     * `vehicleId` (string → reference to `vehicles/{vehicleId}`)
#     * `serviceId` (string → reference to `services/{serviceId}`)
#     * `workshopId` (int)
#     * `price` (double)
#     * `paid` (bool)
#     * `issuedAt` (timestamp)
#     * `createdAt`, `updatedAt` (timestamp)
#
#   * **`payments/{paymentId}`**
#
#     * `invoiceIds` (array of strings)
#     * `subtotal` (double)
#     * `discount` (double)
#     * `netTotal` (double)
#     * `paidAt` (timestamp)
#
# ---
#
# ### `plates/{plate}`
#
# * `uid` (string)
# * `vehicleId` (string)
# * `createdAt` (timestamp)
#
# ---
#
# ### `feedback/{feedbackId}`
#
# * `uid` (string)
# * `serviceId` (string)
# * `email` (string)
# * `rating` (int)
# * `message` (string)
# * `createdAt` (timestamp)
# * `updatedAt` (timestamp)
#
# ---
#
# ### `faqs/{faqId}`
#
# * `question` (string)
# * `answer` (string)
# * `category` (string)
